# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# Simple Linear Regression is a statistical method used to model the relationship between one independent variable (input) and one dependent variable (output), by fitting a straight line through the data points.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Salary_Data.csv")
# X = dataset['YearsExperience']
# y = dataset['Salary']


# X = dataset.drop("Salary", axis=1)
# y = dataset['Salary']

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         64445.,  57189.,  63218.,  56957.,  57081.,  61111.,  67938.,
#         66029.,  83088.,  81363.,  93940.,  91738.,  98273., 101302.,
#        113812., 109431., 105582., 116969., 112635., 122391., 121872.])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
X_test
# Out:
# array([[ 7.1],
#        [ 5.9],
#        [ 4.1],
#        [10.5],
#        [ 9.6],
#        [ 6. ]])

# %%
y_pred
# Out:
# array([ 93159.21641416,  81850.34113166,  64887.02820792, 125201.02971457,
#        116719.3732527 ,  82792.74740521])

# %%
regressor.predict([[5.3]])
# Out:
# array([76195.90349042])

# %%
plt.scatter(X_train, y_train, color = "magenta")
plt.plot(X_train, regressor.predict(X_train), color="Khaki")
plt.title("Salary Vs Experience")
plt.xlabel("Year of Exp")
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X_test, y_test, color = "magenta")
plt.plot(X_train, regressor.predict(X_train), color="Khaki")
plt.title("Salary Vs Experience")
plt.xlabel("Year of Exp")
plt.ylabel('Salary')
plt.show()
